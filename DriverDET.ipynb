# %%
import torch 
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
torch.cuda.is_available()
# Out:
# True

# %%
model=torch.hub.load('ultralytics/yolov5','yolov5s')
# Out:
# Using cache found in /home/hemang/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-2-10 Python-3.10.12 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 3904MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
cap=cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame=cap.read()
    results=model(frame)
    cv2.imshow('Driver State Detection System', np.squeeze(results.render()))

    if cv2.waitKey(10) & 0xFF == ord('f'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
import uuid
import os
import time

# %%
IMAGES_PATH= os.path.join('yolov5','data','images')
labels = ['awake', 'drowsy','head bobbing right','head bobbing left','yawning','distracted right','distracted left']
number_imgs=100

# %%
cap = cv2.VideoCapture(0)

for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(10)
    
    
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
    
        ret, frame = cap.read()
        
        
        imgname=os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
         
        cv2.imwrite(imgname,frame)
        
        
        cv2.imshow('Image Collection', frame)
        
        time.sleep(1)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))
# Out:
# yolov5/data/images/awake.22b5d042-c7c6-11ee-a9d2-bfff11daca2f.jpg

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# yolov5/data/images/awake.243c42c0-c7c6-11ee-a9d2-bfff11daca2f.jpg
# ...
# yolov5/data/images/awake.243c42c1-c7c6-11ee-a9d2-bfff11daca2f.jpg
# ...
# yolov5/data/images/awake.243c42c2-c7c6-11ee-a9d2-bfff11daca2f.jpg
# ...
# yolov5/data/images/awake.243c42c3-c7c6-11ee-a9d2-bfff11daca2f.jpg
# ...
# yolov5/data/images/awake.243c42c4-c7c6-11ee-a9d2-bfff11daca2f.jpg
# ...
# yolov5/data/images/awake.243c42c5-c7c6-11ee-a9d2-bfff11daca2f.jpg
# ...
# yolov5/data/images/awake.243c42c6-c7c6-11ee-a9d2-bfff11daca2f.jpg
# ...
# yolov5/data/images/awake.243c42c7-c7c6-11ee-a9d2-bfff11daca2f.jpg
# ...
# yolov5/data/images/awake.243c42c8-c7c6-11ee-a9d2-bfff11daca2f.jpg
# ...
# yolov5/data/images/awake.243c42c9-c7c6-11ee-a9d2-bfff11daca2f.jpg
# ...
# yolov5/data/images/awake.243c42ca-c7c6-11ee-a9d2-bfff11daca2f.jpg
# ...
# yolov5/data/images/awake.243c42cb-c7c6-11ee-a9d2-bfff11daca2f.jpg
# ...
# yolov5/data/images/awake.243c42cc-c7c6-11ee-a9d2-bfff11daca2f.jpg
# ...
# yolov5/data/images/awake.243c42cd-c7c6-11ee-a9d2-bfff11daca2f.jpg
# ...

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# Cloning into 'labelImg'...
# remote: Enumerating objects: 2097, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 2097 (delta 0), reused 4 (delta 0), pack-reused 2090
# Receiving objects: 100% (2097/2097), 237.14 MiB | 1.81 MiB/s, done.
# Resolving deltas: 100% (1245/1245), done.

# %%
# %pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !cd yolov5 && python3 train.py --img 320 --batch 16 --epochs 500 --data dataset.yml --weights yolov5s.pt
# Out:
# 2024-02-10 10:16:59.309067: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-10 10:16:59.309104: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-10 10:16:59.310315: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp6/weights/best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /home/hemang/.cache/torch/hub/master.zip
# YOLOv5 🚀 2024-2-10 Python-3.10.12 torch-2.2.0+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 3904MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7069459 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = os.path.join('yolov5','data', 'images', 'awake.6b7d4cbc-c797-11ee-9da7-693f11c402c1.jpg')

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 480x640 (no detections)
# Speed: 12.4ms pre-process, 5.1ms inference, 8.7ms NMS per image at shape (1, 3, 480, 640)

# %%
cap=cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame=cap.read()
    results=model(frame)
    cv2.imshow('Driver State Detection System', np.squeeze(results.render()))

    if cv2.waitKey(10) & 0xFF == ord('f'):
        break
cap.release()
cv2.destroyAllWindows()
